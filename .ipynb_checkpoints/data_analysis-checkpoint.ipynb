# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.metrics import accuracy_score
import tensorflow as tf
from sklearn import preprocessing

# %%
pip install --upgrade tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp37-cp37m-win_amd64.whl (430.8 MB)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied, skipping upgrade: h5py>=2.9.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.5 in c:\users\hanif\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp37-cp37m-win_amd64.whl (896 kB)
# Requirement already satisfied, skipping upgrade: wheel<1.0,>=0.32.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.22.0-cp37-cp37m-win_amd64.whl (1.5 MB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-py2.py3-none-win_amd64.whl (13.1 MB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.41.1-cp37-cp37m-win_amd64.whl (3.1 MB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\hanif\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.0)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (45.2.0.post20200210)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\hanif\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\hanif\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\hanif\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (1.5.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\hanif\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied, skipping upgrade: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\hanif\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\hanif\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in c:\users\hanif\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.8)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\hanif\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\hanif\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (2.2.0)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=b624af227801476c563cfeb95ad0b2785d844f054d44e6be861e91bab8ee58fd
#   Stored in directory: c:\users\hanif\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built termcolor
# Installing collected packages: keras, google-pasta, flatbuffers, gast, tensorboard-data-server, absl-py, protobuf, tensorboard-plugin-wit, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, google-auth-oauthlib, markdown, grpcio, tensorboard, opt-einsum, termcolor, tensorflow-io-gcs-filesystem, astunparse, libclang, tensorflow-estimator, keras-preprocessing, typing-extensions, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-4.2.4 flatbuffers-2.0 gast-0.4.0 google-auth-2.3.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.41.1 keras-2.7.0 keras-preprocessing-1.1.2 libclang-12.0.0 markdown-3.3.4 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.7.2 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.22.0 termcolor-1.1.0 typing-extensions-3.10.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv('train-spotify.csv')
test = pd.read_csv('data-dyandra/spotify-predict.csv')

# %%
dataset.head()
# Out:
#    energy  liveness    tempo  speechiness  acousticness  instrumentalness  \
# 0   0.677    0.1080   90.013       0.1360         0.269          0.000917
# 1   0.779    0.3390   80.045       0.1920         0.181          0.000000
# 2   0.844    0.4480  126.931       0.0974         0.111          0.000000
# 3   0.503    0.1400  185.090       0.0310         0.670          0.000000
# 4   0.682    0.0926   98.031       0.1580         0.175          0.000000
#
#    time_signature  danceability  key  duration_ms  loudness  valence  mode  \
# 0               4         0.845   11       219048    -4.798    0.680     0
# 1               4         0.703    7       267750    -4.975    0.595     0
# 2               4         0.612    1       198000    -6.376    0.537     0
# 3               3         0.494    3       217014    -6.838    0.333     1
# 4               4         0.791    5       166851    -7.328    0.672     1
#
#          artist                     track_name  popularity  success
# 0   Jay Wheeler                  La Curiosidad          90        1
# 1          Nane                    Gang În Sus          52        1
# 2       кис-кис                          молчи          56        1
# 3     Justin Lo                             命硬          53        1
# 4  Aya Nakamura  Djadja (feat. Maluma) - Remix          89        1

# %%
dataset.shape
# Out:
# (2755, 17)

# %%
dataset.dtypes
# Out:
# energy              float64
# liveness            float64
# tempo               float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# time_signature        int64
# danceability        float64
# key                   int64
# duration_ms           int64
# loudness            float64
# valence             float64
# mode                  int64
# artist               object
# track_name           object
# popularity            int64
# success               int64
# dtype: object

# %%
dataset.describe()
# Out:
#             energy     liveness        tempo  speechiness  acousticness  \
# count  2755.000000  2755.000000  2755.000000  2755.000000   2755.000000
# mean      0.627565     0.193906   122.701912     0.100565      0.319088
# std       0.192960     0.179644    28.722936     0.094520      0.280886
# min       0.014100     0.019900    57.312000     0.023400      0.000002
# 25%       0.503500     0.096350    99.929500     0.039350      0.068600
# 50%       0.643000     0.121000   121.982000     0.060000      0.239000
# 75%       0.767000     0.214000   141.103000     0.124000      0.530500
# max       0.995000     0.987000   216.334000     0.768000      0.991000
#
#        instrumentalness  time_signature  danceability          key  \
# count       2755.000000     2755.000000   2755.000000  2755.000000
# mean           0.036900        3.960799      0.653376     5.242468
# std            0.146130        0.301151      0.155689     3.598395
# min            0.000000        1.000000      0.130000     0.000000
# 25%            0.000000        4.000000      0.550000     2.000000
# 50%            0.000002        4.000000      0.672000     5.000000
# 75%            0.000357        4.000000      0.773000     8.000000
# max            0.966000        5.000000      0.974000    11.000000
#
#          duration_ms     loudness      valence         mode   popularity  \
# count    2755.000000  2755.000000  2755.000000  2755.000000  2755.000000
# mean   215250.793466    -7.189768     0.526309     0.578947    56.861343
# std     66377.017843     3.204799     0.227881     0.493818    18.282669
# min     66958.000000   -26.459000     0.034900     0.000000     0.000000
# 25%    176114.000000    -8.700000     0.347000     0.000000    47.000000
# 50%    201033.000000    -6.645000     0.533000     1.000000    58.000000
# 75%    235698.500000    -5.096000     0.704000     1.000000    69.000000
# max    729760.000000     1.509000     0.977000     1.000000   100.000000
#
#            success
# count  2755.000000
# mean      0.454083
# std       0.497978
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
dataset.isnull().sum()
# Out:
# energy              0
# liveness            0
# tempo               0
# speechiness         0
# acousticness        0
# instrumentalness    0
# time_signature      0
# danceability        0
# key                 0
# duration_ms         0
# loudness            0
# valence             0
# mode                0
# artist              0
# track_name          0
# popularity          0
# success             0
# dtype: int64

# %%
scaler = MinMaxScaler() 

scaled_values = scaler.fit_transform(dataset[['tempo', 'key', 'duration_ms','loudness', 'popularity']]) 
dataset[['tempo', 'key', 'duration_ms','loudness', 'popularity']] = scaled_values

scaled_values = scaler.fit_transform(test[['tempo', 'key', 'duration_ms','loudness', 'popularity']]) 
test[['tempo', 'key', 'duration_ms','loudness', 'popularity']] = scaled_values

dataset.describe()
# Out:
#             energy     liveness        tempo  speechiness  acousticness  \
# count  2755.000000  2755.000000  2755.000000  2755.000000   2755.000000
# mean      0.627565     0.193906     0.411200     0.100565      0.319088
# std       0.192960     0.179644     0.180622     0.094520      0.280886
# min       0.014100     0.019900     0.000000     0.023400      0.000002
# 25%       0.503500     0.096350     0.267998     0.039350      0.068600
# 50%       0.643000     0.121000     0.406673     0.060000      0.239000
# 75%       0.767000     0.214000     0.526915     0.124000      0.530500
# max       0.995000     0.987000     1.000000     0.768000      0.991000
#
#        instrumentalness  time_signature  danceability          key  \
# count       2755.000000     2755.000000   2755.000000  2755.000000
# mean           0.036900        3.960799      0.653376     0.476588
# std            0.146130        0.301151      0.155689     0.327127
# min            0.000000        1.000000      0.130000     0.000000
# 25%            0.000000        4.000000      0.550000     0.181818
# 50%            0.000002        4.000000      0.672000     0.454545
# 75%            0.000357        4.000000      0.773000     0.727273
# max            0.966000        5.000000      0.974000     1.000000
#
#        duration_ms     loudness      valence         mode   popularity  \
# count  2755.000000  2755.000000  2755.000000  2755.000000  2755.000000
# mean      0.223736     0.688974     0.526309     0.578947     0.568613
# std       0.100146     0.114588     0.227881     0.493818     0.182827
# min       0.000000     0.000000     0.034900     0.000000     0.000000
# 25%       0.164689     0.634976     0.347000     0.000000     0.470000
# 50%       0.202285     0.708453     0.533000     1.000000     0.580000
# 75%       0.254587     0.763837     0.704000     1.000000     0.690000
# max       1.000000     1.000000     0.977000     1.000000     1.000000
#
#            success
# count  2755.000000
# mean      0.454083
# std       0.497978
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
plt.figure(figsize=(12,12))

corr = dataset.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask, 1)] = True

sns.heatmap(corr, mask=mask, annot=True, cmap="Greens")

# %%
def plot_dist_reg (n_rows, n_elem, axis, features, colors, titles):
    fig, (axis) = plt.subplots(n_rows, n_elem, figsize=(15, 5))   
    itens = len(axis)
    i = 0
    while i < itens:
        axis[i] = sns.regplot(x = dataset[features[i][0]], y = dataset[features[i][1]], data=dataset, color=colors[i], line_kws={'color':'black'}, ax=axis[i])
        axis[i].set_title(titles[i])
        i+=1
    plt.subplots_adjust(wspace=0.5)
    plt.show()

# %%
# Features with high positive correlation: energy and loudness
# Features with high negative correlation: energy and acousticness
axis = ['ax0','ax1']
features = [['energy','loudness'],['energy','acousticness']]
colors = ['#48d66c', '#bd36d8']
titles = ['Energy x Loudness', 'Energy x Acousticness']
plot_dist_reg(1, 2, axis, features, colors, titles)

# %%
def show_values_on_bars(ax, h_v, space):
    if h_v == "v":
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height()
            value = int(p.get_height())
            ax.text(_x, _y, value, ha="center") 
    elif h_v == "h":
        for p in ax.patches:
            _x = p.get_x() + p.get_width() + float(space)
            _y = p.get_y() + p.get_height()
            value = int(p.get_width())
            ax.text(_x, _y, value, ha="left")

# %%
# Class analysis
plt.figure(1 , figsize = (15 , 5))
ax = sns.countplot(y = 'success', data = dataset, palette="Greens")
ax.set_title('Number of hits (1) and non hits (0) songs')
show_values_on_bars(ax, "h", 10)
plt.show()

# %%
# Get only hit songs
hits_df = dataset[dataset['success'] == 1]

# %%
top_artists = hits_df['artist'].value_counts()[:5]
name = top_artists.index.tolist()
amount = top_artists.values.tolist()

plt.figure(1 , figsize = (15, 5))
ax = sns.barplot(x = name, y = amount, palette="Purples_d")
ax.set_title('Artists with more hit songs')
show_values_on_bars(ax, "v", 10)
plt.show()

# %%
valence = hits_df['valence'].value_counts()
valence_value = valence.index.tolist()
amount = valence.values.tolist()
i, high, low = 0, 0, 0

for v in valence_value:
    if (float(v) >= 0.5):
        high += amount[i]
    else:
        low += amount[i]
    i += 1

print('Positive tracks: ', high)
print('Negative tracks: ', low)
# Out:
# Positive tracks:  704
# Negative tracks:  547

# %%
# Split features and class data and drop irrelevant columns
X = dataset.drop(['success', 'artist', 'track_name'], axis=1).values
y = dataset[['success']].values

# Split train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Create the classifier object
rf_model = RandomForestClassifier(n_estimators = 100)

# Train
rf_model.fit(X_train, y_train.ravel())

# Predict
y_pred = rf_model.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7218863361547763

# %%
# Create the classifier object
lg_model = LogisticRegression()

# Train
lg_model.fit(X_train, y_train.ravel())

# Predict
y_pred = lg_model.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.6952841596130592

# %%
# Create the classifier object
svm_model = svm.SVC(kernel='linear')

# Train
svm_model.fit(X_train, y_train.ravel())

# Predict
y_pred = svm_model.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.6977025392986699

# %%
# Drop irrelevant columns
df_test = test.drop(['artist', 'track_name'], axis=1).values

# Predict
test_predict = rf_model.predict(df_test)

# Get only predict hit songs
hits_predict = (test_predict == 1).sum()
print(hits_predict, "out of", len(test_predict), "was predicted as HIT")
# Out:
# 22 out of 100 was predicted as HIT

# %%
df = pd.DataFrame({'Song': test['track_name'], 'Artist': test['artist'], 'Predict': test_predict})
df.sort_values(by=['Predict'], inplace=True, ascending=False)
df
# Out:
#                                        Song        Artist  Predict
# 50                              ESCAPE PLAN  Travis Scott        1
# 16                    Smokin Out The Window    Bruno Mars        1
# 52                                 Soufside         Latto        1
# 46                                    MAFIA  Travis Scott        1
# 65                                      NEO         Aminé        1
# ..                                      ...           ...      ...
# 36                                New Tooth    Rich Brian        0
# 35                              Home Videos     Clubhouse        0
# 34                               Get Better         alt-J        0
# 33  Cool, Calm & Collected (feat. Swae Lee)        Pressa        0
# 99   Scared - from the "Bruised" Soundtrack    City Girls        0
#
# [100 rows x 3 columns]

# %%
data = pd.read_csv("data-dyandra/spotify-train.csv")
data.head()
# Out:
#    energy  liveness    tempo  speechiness  acousticness  instrumentalness  \
# 0   0.775    0.1080  126.984       0.1080        0.2770          0.000000
# 1   0.611    0.1160  185.727       0.0467        0.0228          0.000000
# 2   0.560    0.1150  162.794       0.1430        0.0909          0.000000
# 3   0.708    0.0771  150.976       0.2400        0.4180          0.000000
# 4   0.683    0.3220   92.014       0.0703        0.1960          0.000064
#
#    time_signature  danceability  key  duration_ms  loudness  valence  mode  \
# 0               4         0.817   10       234334    -4.767   0.8060     0
# 1               3         0.410    4       184448    -8.271   0.0899     0
# 2               4         0.599    0       168391    -8.569   0.3940     0
# 3               4         0.698    1       156013    -6.118   0.6210     0
# 4               4         0.776    9       180248    -4.078   0.7260     1
#
#         artist           track_name  popularity  success
# 0  Wiz Khalifa           The Thrill          79        1
# 1   Elley Duhé  MIDDLE OF THE NIGHT          67        1
# 2  Irina Rimes     Pentru totdeauna          50        1
# 3        Sobel              Bandyta          66        1
# 4         Duki     Ley de Atracción          75        1

# %%
datatest = pd.read_csv('data-dyandra/spotify-predict.csv')

# %%
data = data.sample(frac=1)
data.head()
# Out:
#       energy  liveness    tempo  speechiness  acousticness  instrumentalness  \
# 2616   0.731    0.1610   80.040       0.1990        0.2700          0.000004
# 2689   0.704    0.0979   93.993       0.0716        0.2820          0.000000
# 1486   0.325    0.0658   81.325       0.0447        0.9090          0.000773
# 1597   0.862    0.1350  170.102       0.0927        0.6060          0.000000
# 1976   0.744    0.4660  128.047       0.0368        0.0319          0.000458
#
#       time_signature  danceability  key  duration_ms  loudness  valence  mode  \
# 2616               4         0.868   11       211100    -6.401    0.852     0
# 2689               4         0.692    0       202109    -8.109    0.608     1
# 1486               3         0.520    2       195000   -15.560    0.167     1
# 1597               4         0.707    1       169296    -4.549    0.816     0
# 1976               4         0.639    6       240533    -8.377    0.825     0
#
#                 artist                      track_name  popularity  success
# 2616     Planta E Raiz                   É Desse Jeito          38        0
# 2689        Rafa Valle                         Lá Fora          31        0
# 1486    Mariana Volker                 Cheia de Dobras          32        0
# 1597  Marília Mendonça  Hoje Somos Só Metade - Ao Vivo          63        0
# 1976             Foals                       My Number           6        0

# %%
data.drop(["track_name","artist"],axis=1,inplace=True)

# %%
unscaled_inputs = data.iloc[:,0:-1]
target = data.iloc[:,[-1]]

# %%
target
# Out:
#       success
# 2616        0
# 2689        0
# 1486        0
# 1597        0
# 1976        0
# ...       ...
# 2801        0
# 846         1
# 234         1
# 2421        0
# 2024        0
#
# [2897 rows x 1 columns]

# %%
scaled_inputs = preprocessing.scale(unscaled_inputs)

# %%
scaled_inputs
# Out:
# array([[ 0.62847871, -0.13709997, -1.44722588, ...,  1.45563748,
#         -1.1462538 , -0.96072114],
#        [ 0.50021372, -0.52847983, -0.96181484, ...,  0.38233554,
#          0.87240714, -1.31825658],
#        [-1.30024681, -0.72758115, -1.402522  , ..., -1.55752576,
#          0.87240714, -1.26718009],
#        ...,
#        [ 0.04416039,  0.92353325, -1.17023579, ...,  1.38085825,
#         -1.1462538 ,  0.92910907],
#        [ 1.17479259, -0.37279624, -0.23166312, ...,  0.77382682,
#          0.87240714,  0.7248031 ],
#        [-0.33113349, -0.54460642,  0.09876289, ...,  0.50990011,
#         -1.1462538 , -2.90162784]])

# %%
samples_count = scaled_inputs.shape[0]
#
train_samples_count = int(0.8*samples_count)
validation_samples_count = int(0.1*samples_count)
test_samples_count = samples_count - train_samples_count - validation_samples_count

# %%
# train:
train_inputs = scaled_inputs[:train_samples_count]
train_targets = target[:train_samples_count]

# %%
# validation:
validation_inputs = scaled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = target[train_samples_count:train_samples_count+validation_samples_count]

# %%
# test:
test_inputs = scaled_inputs[train_samples_count+validation_samples_count:]
test_targets = target[train_samples_count+validation_samples_count:]

# %%
# Print the number of targets that are 1s, the total number of samples, and the proportion for training, validation, and test.
print(np.sum(train_targets), train_samples_count, np.sum(train_targets) / train_samples_count)
print(np.sum(validation_targets), validation_samples_count, np.sum(validation_targets) / validation_samples_count)
print(np.sum(test_targets), test_samples_count, np.sum(test_targets) / test_samples_count)
# Out:
# success    1010
# dtype: int64 2317 success    0.435909
# dtype: float64
# success    132
# dtype: int64 289 success    0.456747
# dtype: float64
# success    120
# dtype: int64 291 success    0.412371
# dtype: float64

# %%
test_targets
# Out:
#       success
# 1340        0
# 875         1
# 1237        1
# 792         1
# 2681        0
# ...       ...
# 2801        0
# 846         1
# 234         1
# 2421        0
# 2024        0
#
# [291 rows x 1 columns]

# %%
# Save the three datasets in *.npz.
# We will see that it is extremely valuable to name them in such a coherent way!

np.savez('Spotify_data_train', inputs=train_inputs, targets=train_targets)
np.savez('Spotify_data_validation', inputs=validation_inputs, targets=validation_targets)
np.savez('Spotify_data_test', inputs=test_inputs, targets=test_targets)

# %%
npz = np.load('Spotify_data_train.npz')
# we extract the inputs using the keyword under which we saved them
# to ensure that they are all floats, let's also take care of that
train_inputs = npz['inputs'].astype(np.float)
# targets must be int because of sparse_categorical_crossentropy (we want to be able to smoothly one-hot encode them)
train_targets = npz['targets'].astype(np.int)

# we load the validation data in the temporary variable
npz = np.load('Spotify_data_validation.npz')
# we can load the inputs and the targets in the same line
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# we load the test data in the temporary variable
npz = np.load('Spotify_data_test.npz')
# we create 2 variables that will contain the test inputs and the test targets
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %%
# Set the input and output sizes
input_size = 15 # count of features
output_size = 2 # count of targets
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 70 # counts of neurons
    
# define how the model will look like
model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 3nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])

# %%
# we define the optimizer we'd like to use, 
# the loss function, 
# and the metrics we are interested in obtaining at each iteration
#custom_optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# That's where we train the model we have built.
# set the batch size
batch_size = 300
# set a maximum number of training epochs
max_epochs = 20

# fit the model
# note that this time the train, validation and test data are not iterable
history = model.fit(  train_inputs, # train inputs
                      train_targets, # train targets
                      batch_size=batch_size, # batch size
                      epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
                      # callbacks are functions called by a task when a task is completed
                      # task here is to check if val_loss is increasing
                      #callbacks=[early_stopping], # early stopping
                      validation_data=(validation_inputs, validation_targets), # validation data
                      verbose = 2 # making sure we get enough information about the training process
          )
# Out:
# Epoch 1/20
# 8/8 - 1s - loss: 0.6998 - accuracy: 0.5084 - val_loss: 0.6512 - val_accuracy: 0.5675 - 1s/epoch - 145ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 0.6228 - accuracy: 0.6262 - val_loss: 0.5870 - val_accuracy: 0.6747 - 47ms/epoch - 6ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 0.5681 - accuracy: 0.7177 - val_loss: 0.5387 - val_accuracy: 0.7439 - 49ms/epoch - 6ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 0.5306 - accuracy: 0.7320 - val_loss: 0.5075 - val_accuracy: 0.7405 - 41ms/epoch - 5ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 0.5047 - accuracy: 0.7458 - val_loss: 0.4983 - val_accuracy: 0.7439 - 65ms/epoch - 8ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 0.4877 - accuracy: 0.7549 - val_loss: 0.4913 - val_accuracy: 0.7578 - 66ms/epoch - 8ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 0.4765 - accuracy: 0.7644 - val_loss: 0.4868 - val_accuracy: 0.7543 - 47ms/epoch - 6ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 0.4684 - accuracy: 0.7708 - val_loss: 0.4865 - val_accuracy: 0.7682 - 62ms/epoch - 8ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 0.4595 - accuracy: 0.7790 - val_loss: 0.4855 - val_accuracy: 0.7716 - 42ms/epoch - 5ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 0.4510 - accuracy: 0.7808 - val_loss: 0.4796 - val_accuracy: 0.7612 - 55ms/epoch - 7ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 0.4448 - accuracy: 0.7864 - val_loss: 0.4811 - val_accuracy: 0.7543 - 43ms/epoch - 5ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 0.4386 - accuracy: 0.7898 - val_loss: 0.4809 - val_accuracy: 0.7751 - 53ms/epoch - 7ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 0.4329 - accuracy: 0.7928 - val_loss: 0.4825 - val_accuracy: 0.7751 - 45ms/epoch - 6ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 0.4266 - accuracy: 0.7972 - val_loss: 0.4786 - val_accuracy: 0.7716 - 46ms/epoch - 6ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 0.4220 - accuracy: 0.7984 - val_loss: 0.4831 - val_accuracy: 0.7682 - 44ms/epoch - 5ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 0.4156 - accuracy: 0.8023 - val_loss: 0.4800 - val_accuracy: 0.7716 - 46ms/epoch - 6ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 0.4095 - accuracy: 0.8097 - val_loss: 0.4838 - val_accuracy: 0.7682 - 44ms/epoch - 6ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 0.4048 - accuracy: 0.8062 - val_loss: 0.4777 - val_accuracy: 0.7716 - 46ms/epoch - 6ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 0.4003 - accuracy: 0.8166 - val_loss: 0.4868 - val_accuracy: 0.7647 - 44ms/epoch - 6ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 0.3951 - accuracy: 0.8183 - val_loss: 0.4830 - val_accuracy: 0.7751 - 47ms/epoch - 6ms/step

# %%
# Get training and test loss histories
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, validation_loss, 'b-')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.7595
#
# Test loss: 0.50. Test accuracy: 75.95%

# %%
# Drop irrelevant columns
df_test = datatest.drop(['artist', 'track_name'], axis=1).values

# %%
# Drop irrelevant columns
df_test = datatest.drop(['artist', 'track_name'], axis=1).values

# Predict
test_predict = model.evaluate(df_test)

# Get only predict hit songs
hits_predict = (test_predict == 1).sum()
print(hits_predict, "out of", len(test_predict), "was predicted as HIT")
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-685d9cbdae1d> in <module>
#       6
#       7 # Get only predict hit songs
# ----> 8 hits_predict = (test_predict == 1).sum()
#       9 print(hits_predict, "out of", len(test_predict), "was predicted as HIT")
#
# AttributeError: 'bool' object has no attribute 'sum'

# %%
test_scaled = preprocessing.scale(df_test)

# %%
testing_prediction=model.predict(test_scaled)

hits_predict = (testing_prediction == 1).sum()
print(hits_predict, "out of", len(testing_prediction), "was predicted as HIT")
# Out:
# 0 out of 100 was predicted as HIT

# %%
test_inputs[0]
# Out:
# array([-0.61141627, -0.56383427, -0.38125586, -0.69934359, -1.14559342,
#        -0.26311576,  0.14203315, -1.96831643, -0.65016724,  1.50211611,
#         0.11868345, -1.80825614, -1.1462538 , -2.90162784])

# %%
test_scaled[0]
# Out:
# array([ 0.69653363,  0.12722175, -1.21329101, -0.51373271, -0.8715939 ,
#        -0.20763297,  0.15249857, -0.11046371,  0.62440197, -0.96729273,
#         1.33607227, -0.5603925 ,  0.81649658, -0.84490331])

# %%
df = pd.DataFrame({'Song': datatest['track_name'], 'Artist': datatest['artist'], 'Predict': test_predict})
df.sort_values(by=['Predict'], inplace=True, ascending=False)
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-77-01bf158f8f99> in <module>
# ----> 1 df = pd.DataFrame({'Song': datatest['track_name'], 'Artist': datatest['artist'], 'Predict': test_predict})
#       2 df.sort_values(by=['Predict'], inplace=True, ascending=False)
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     480     elif subarr.ndim > 1:
#     481         if isinstance(data, np.ndarray):
# --> 482             raise Exception("Data must be 1-dimensional")
#     483         else:
#     484             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional
